# %% [markdown]
# **Importing Libraries**

# %%
import os
import sys
import numpy as np
import pandas as pd
import string
import nltk
import threading # will potentially use multi-threading
from nltk.stem.porter import *
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
from bs4 import BeautifulSoup
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/snehachoudhary/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Generating documents from smg files and TOKENIZING and Stemming**

# %%
def init_document():
    """ function: init_document
        -----------------------
        initialize new empty document skeleton
        :returns: dictionary @document of document fields
        @dictionary['topics'] is a list representing topic class labels
        @dictionary['places'] is a list representing place class labels
        @dictionary['words'] is a dictionary
        @dictionary['words']['title'] is a list for the title text terms
        @dictionary['words']['body'] is a list for the body text terms
    """
    #document = { 'topics' : [], 'places' : [], 'words' : dict([]) }
    document = { 'topics' : [], 'places' : [], 'title' : [], 'body' : []}
    #document['words']['title'] = []
    #document['words']['body']  = []
    return document

def populate_class_label(document, article):
    """ function: populate_class_label
        ------------------------------
        extract topics/places from @article and fill @document
        :param document: formatted dictionary object representing a document
        :param article:  formatted parse tree built from unformatted data
        @article is a 'reuter' child of the original file parsetree
    """
    for topic in article.topics.children:
        #print("before ",topic.text)
        #print("after ",topic.text.encode('ascii', 'ignore'))
        document['topics'].append(topic.text)
    for place in article.places.children:
        document['places'].append(place.text)

def populate_word_list(document, article):
    """ function: populate_word_list
        ----------------------------
        extract title/body words from @article, preprocess, and fill @document
        :param document: formatted dictionary object representing a document
        :param article:  formatted parse tree built from unformatted data
            @article is a 'reuter' child of the original file parsetree
    """
    text = article.find('text')
    title = text.title
    body = text.body
    if title != None:
        #print("title is ",title)
        #document['words']['title'] = title.text.split(' ')
        document['title'] = tokenize(title.text)
    if body != None:
        #print("body is ",body)
        document['body'] = tokenize(body.text)
        #document['words']['body'] = body.text.split(' ')

def tokenize(text):
    """ function: tokenize
        ------------------
        generate list of tokens given a block of @text;
        :param text: string representing text field (title or body)
        :returns: list of strings of tokenized & sanitized words
    """
    # encode unicode to string
    #ascii = text.encode('ascii', 'ignore')
    
    #remove digits
    
    translation_digits = str.maketrans(string.ascii_letters, string.ascii_letters, string.digits)
    no_digits = text.translate(translation_digits)
    #remove punctuation
    translation_punc = str.maketrans(string.ascii_letters, string.ascii_letters, string.punctuation)
    no_punctuation = no_digits.translate(translation_punc)
    # tokenize
    tokens = nltk.word_tokenize(no_punctuation)
    # remove stopwords - assume 'reuter'/'reuters' are also irrelevant
    no_stop_words = [w for w in tokens if not w in stopwords.words('english')]
    # filter out non-english words
    eng = [y for y in no_stop_words if wordnet.synsets(y)]
    # lemmatization process
    lemmas = []
    lmtzr = WordNetLemmatizer()
    for token in eng:
        lemmas.append(lmtzr.lemmatize(token))
    # stemming process
    stems = []
    stemmer = PorterStemmer()
    for token in lemmas:
        stems.append(stemmer.stem(token))
    # remove short stems
    terms = [x for x in stems if len(x) >= 4]
    return terms

def generate_document(text):
    """ function: generate_document
        ---------------------------
        extract class labels & tokenized (and sanitized) title/body text
        :param text: parsetree of 'reuter' child in original parsetree
        :returns: dictionary representing fields of single document entity
    """
    document = init_document()
    populate_class_label(document, text)
    populate_word_list(document, text)
    # UNCOMMENT WHEN DEBUGGING
    #print(document)
    return document

###############################################################################
############ function(s) for generating parse tree from .sgm files ############
###############################################################################

def generate_tree(text):
    """ function: generate_tree
        -----------------------
        extract well-formatted tree from poorly-formatted sgml @text
        :param text: string representing sgml text for a set of articles
        :returns: parsetree @tree of the structured @text
    """
    return BeautifulSoup(text, "html.parser")

###############################################################################
########## function(s) for generating parse trees & document objects ##########
###############################################################################

def parse_documents():
    """ function: parse_document
        ------------------------
        extract list of Document objects from token list
        :returns: list of document entities generated by generate_document()
    """
    documents = []
    # generate well-formatted document set for each file
    for file in os.listdir('DATA2'):
        # open 'reut2-XXX.sgm' file from /data directory
        data = open(os.path.join(os.getcwd(), "DATA2", file), 'r')
        print("file",file)
        text = data.read()
        data.close()
        tree = generate_tree(text.lower())
        # separate segments & generate documents
        for reuter in tree.find_all("reuters"):
            document = generate_document(reuter)
            documents.append(document)
        print("Finished extracting information from file:", file)
    return documents

###############################################################################
##################### function(s) for generating lexicon ######################
###############################################################################

def generate_lexicon(documents):
    """ function: generate_lexicon
        --------------------------
        generate title/body lexicon for feature selection
        :param documents: objects to generate lexicon information
        :returns: dictionary of sets for title & body lexicons
    """
    lexicon = { 'title' : set(), 'body' : set() }
    for document in documents:
        for term in document['words']['title']:
            lexicon['title'].add(term)
        for term in document['words']['body']:
            lexicon['body'].add(term)
    return lexicon

###############################################################################
################## main function - single point of execution ##################
###############################################################################

def main(argv):
    """ function: main
        --------------
        sanitize input files into well-formatted, processable objects
        generate dataset (feature vectors, class labels) for .sgm file set:
        :param argv: command line arguments - no purpose at the moment
    """
    # generate list of document objects for feature selection
    print('Generating document objects. This may take some time...')
    #documents = parse_documents()

if __name__ == "__main__":
    main(sys.argv[1:])
# Out:
# Generating document objects. This may take some time...

# %% [markdown]
# **Calling parse_documents function and storing it in documents object**

# %%
documents = parse_documents()
# Out:
# file reut2-004.sgm
# Finished extracting information from file: reut2-004.sgm
# file reut2-010.sgm
# Finished extracting information from file: reut2-010.sgm
# file reut2-011.sgm
# Finished extracting information from file: reut2-011.sgm
# file reut2-005.sgm
# Finished extracting information from file: reut2-005.sgm
# file reut2-013.sgm
# Finished extracting information from file: reut2-013.sgm
# file reut2-007.sgm
# Finished extracting information from file: reut2-007.sgm
# file reut2-006.sgm
# Finished extracting information from file: reut2-006.sgm
# file reut2-012.sgm
# Finished extracting information from file: reut2-012.sgm
# file reut2-016.sgm
# Finished extracting information from file: reut2-016.sgm
# file reut2-002.sgm
# Finished extracting information from file: reut2-002.sgm
# file reut2-003.sgm
# Finished extracting information from file: reut2-003.sgm
# file reut2-001.sgm
# Finished extracting information from file: reut2-001.sgm
# file reut2-015.sgm
# Finished extracting information from file: reut2-015.sgm
# file reut2-014.sgm
# Finished extracting information from file: reut2-014.sgm
# file reut2-000.sgm
# Finished extracting information from file: reut2-000.sgm
# file reut2-019.sgm
# Finished extracting information from file: reut2-019.sgm
# file reut2-018.sgm
# Finished extracting information from file: reut2-018.sgm
# file reut2-020.sgm
# Finished extracting information from file: reut2-020.sgm
# file reut2-008.sgm
# Finished extracting information from file: reut2-008.sgm
# file reut2-009.sgm
# Finished extracting information from file: reut2-009.sgm
# file reut2-021.sgm
# Finished extracting information from file: reut2-021.sgm

# %%
documents
# Out:
# [{'topics': [],
#   'places': ['canada'],
#   'title': ['major', 'impact', 'remov'],
#   'body': ['said',
#    'expect',
#    'earlier',
#    'report',
#    'remov',
#    'jone',
#    'industri',
#    'index',
#    'make',
#    'major',
#    'impact',
#    'compani',
#    'stock',
#    'think',
#    'individu',
#    'institut',
#    'share',
#    'jone',
#    'spokesman',
#    'said',
#    'repli',
#    'queri',
#    'close',
#    'lower',
#    'second',
#    'activ',
#    'trade',
#    'toronto',
#    'stock',
#    'exchang',
#    'wall',
#    'street',
#    'journal',
#    'select',
#    'index',
#    'said',
#    'drop',
#    'make',
#    'index',
#    'repres',
#    'market',
#    'world',
#    'largest',
#    'nickel',
#    'produc',
#    'member',
#    'index',
#    'replac',
#    'effect',
#    'tomorrow',
#    'nickel',
#    'analyst',
#    'marten',
#    'cochran',
#    'murray',
#    'said',
#    'remov',
#    'index',
#    'like',
#    'spark',
#    'sell',
#    'pressur',
#    'stock',
#    'investor',
#    'suddenli',
#    'well',
#    'stock',
#    'elimin',
#    'invest',
#    'said',
#    'marten',
#    'move',
#    'unlik',
#    'seriou',
#    'impact',
#    'stock',
#    'struggl',
#    'recent',
#    'year',
#    'sharpli',
#    'lower',
#    'nickel',
#    'price',
#    'earn',
#    'fell',
#    'previou',
#    'year']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['former', 'empir', 'carolina', 'exec', 'sentenc'],
#   'body': ['mason',
#    'former',
#    'presid',
#    'chief',
#    'oper',
#    'offic',
#    'empir',
#    'carolina',
#    'maker',
#    'today',
#    'sentenc',
#    'manhattan',
#    'feder',
#    'court',
#    'year',
#    'jail',
#    'involv',
#    'kickback',
#    'scheme',
#    'plead',
#    'guilti',
#    'charg',
#    'conspiraci',
#    'evas',
#    'file',
#    'fals',
#    'corpor',
#    'return',
#    'defraud',
#    'compani',
#    'sharehold',
#    'also',
#    'fine',
#    'charg',
#    'demand',
#    'kickback',
#    'sale',
#    'repres',
#    'turn',
#    'portion',
#    'condit',
#    'busi',
#    'empir']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['doctor', 'find', 'link', 'smallpox', 'viru'],
#   'body': ['discoveri',
#    'complic',
#    'search',
#    'vaccin',
#    'team',
#    'armi',
#    'doctor',
#    'said',
#    'uncov',
#    'interact',
#    'viru',
#    'viru',
#    'protect',
#    'smallpox',
#    'physician',
#    'walter',
#    'reed',
#    'armi',
#    'institut',
#    'research',
#    'said',
#    'appar',
#    'expos',
#    'viru',
#    'develop',
#    'diseas',
#    'receiv',
#    'smallpox',
#    'vaccin',
#    'militari',
#    'test',
#    'recruit',
#    'vaccin',
#    'find',
#    'report',
#    'england',
#    'journal',
#    'medicin',
#    'signific',
#    'scientist',
#    'begun',
#    'work',
#    'vaccin',
#    'reli',
#    'smallpox',
#    'vaccin',
#    'case',
#    'report',
#    'rais',
#    'provoc',
#    'question',
#    'concern',
#    'ultim',
#    'safeti',
#    'vaccin',
#    'said',
#    'group',
#    'robert',
#    'report',
#    'also',
#    'throw',
#    'question',
#    'belief',
#    'held',
#    'scientist',
#    'smallpox',
#    'vaccin',
#    'expos',
#    'peopl',
#    'milder',
#    'protect',
#    'form',
#    'diseas',
#    'known',
#    'cowpox',
#    'modifi',
#    'protect',
#    'peopl',
#    'host',
#    'diseas']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['birth', 'control', 'pill', 'help', 'prevent', 'cancer', 'studi'],
#   'body': ['doctor',
#    'center',
#    'diseas',
#    'control',
#    'atlanta',
#    'said',
#    'evid',
#    'birth',
#    'control',
#    'pill',
#    'help',
#    'provid',
#    'protect',
#    'cancer',
#    'ovari',
#    'even',
#    'pill',
#    'taken',
#    'month',
#    'studi',
#    'report',
#    'england',
#    'journal',
#    'medicin',
#    'also',
#    'found',
#    'variou',
#    'type',
#    'oral',
#    'contracept',
#    'market',
#    'equal',
#    'effect',
#    'lower',
#    'rate',
#    'ovarian',
#    'cancer',
#    'research',
#    'estim',
#    'birth',
#    'control',
#    'pill',
#    'countri',
#    'probabl',
#    'prevent',
#    'case',
#    'ovarian',
#    'cancer',
#    'woman',
#    'taken',
#    'oral',
#    'contracept',
#    'move',
#    'group',
#    'highest',
#    'risk',
#    'epitheli',
#    'ovarian',
#    'cancer',
#    'declin',
#    'incid',
#    'seriou',
#    'diseas',
#    'said',
#    'specif',
#    'team',
#    'howard',
#    'found',
#    'oral',
#    'contracept',
#    'even',
#    'month',
#    'reduc',
#    'risk',
#    'epitheli',
#    'ovarian',
#    'cancer',
#    'percent',
#    'woman',
#    'year',
#    'effect',
#    'probabl',
#    'take',
#    'five',
#    'year',
#    'becom',
#    'appar',
#    'persist',
#    'long',
#    'oral',
#    'contracept',
#    'moreov',
#    'protect',
#    'exist',
#    'regardless',
#    'formul',
#    'oral',
#    'contracept',
#    'said']},
#  {'topics': ['interest', 'retail', 'ipi'],
#   'places': ['usa'],
#   'title': ['econom', 'data', 'debt', 'futur', 'outlook'],
#   'body': ['econom',
#    'data',
#    'week',
#    'determin',
#    'interest',
#    'rate',
#    'futur',
#    'break',
#    'month',
#    'trade',
#    'rang',
#    'financi',
#    'analyst',
#    'said',
#    'market',
#    'expect',
#    'februari',
#    'retail',
#    'sale',
#    'thursday',
#    'industri',
#    'product',
#    'friday',
#    'show',
#    'healthi',
#    'gain',
#    'figur',
#    'within',
#    'slightli',
#    'expect',
#    'posit',
#    'market',
#    'analyst',
#    'said',
#    'impress',
#    'resili',
#    'bond',
#    'right',
#    'said',
#    'smith',
#    'harri',
#    'analyst',
#    'treasuri',
#    'bond',
#    'futur',
#    'came',
#    'pressur',
#    'today',
#    'trader',
#    'link',
#    'persist',
#    'firm',
#    'feder',
#    'fund',
#    'rate',
#    'rise',
#    'price',
#    'howev',
#    'suffici',
#    'sell',
#    'interest',
#    'break',
#    'chart',
#    'support',
#    'june',
#    'contract',
#    'fail',
#    'materi',
#    'particip',
#    'sold',
#    'bond',
#    'futur',
#    'earli',
#    'quickli',
#    'cover',
#    'short',
#    'posit',
#    'said',
#    'expect',
#    'strong',
#    'number',
#    'come',
#    'expect',
#    'wont',
#    'market',
#    'said',
#    'said',
#    'consensu',
#    'estim',
#    'sector',
#    'retail',
#    'sale',
#    'rise',
#    'dean',
#    'analyst',
#    'karen',
#    'gibb',
#    'said',
#    'retail',
#    'sale',
#    'figur',
#    'market',
#    'forecast',
#    'give',
#    'boost',
#    'debt',
#    'futur',
#    'rang',
#    'sector',
#    'retail',
#    'sale',
#    'industri',
#    'product',
#    'produc',
#    'price',
#    'index',
#    'friday',
#    'expect',
#    'show',
#    'increas',
#    'retail',
#    'sale',
#    'tell',
#    'fill',
#    'gibb',
#    'said',
#    'refer',
#    'chart',
#    'june',
#    'bond',
#    'creat',
#    'friday',
#    'june',
#    'bond',
#    'close',
#    'today',
#    'also',
#    'debt',
#    'futur',
#    'direct',
#    'addit',
#    'feder',
#    'fund',
#    'rate',
#    'direct',
#    'crude',
#    'price',
#    'said',
#    'carrol',
#    'futur',
#    'analyst',
#    'singer',
#    'higher',
#    'fund',
#    'rate',
#    'firm',
#    'price',
#    'preclud',
#    'market',
#    'break',
#    'trade',
#    'rang',
#    'last',
#    'time',
#    'market',
#    'approach',
#    'rang',
#    'singer',
#    'said',
#    'order',
#    'bond',
#    'break',
#    'rang',
#    'june',
#    'contract',
#    'crude',
#    'ralli',
#    'need',
#    'cours',
#    'pull',
#    'back',
#    'littl',
#    'singer',
#    'said',
#    'fund',
#    'alreadi',
#    'back',
#    'level',
#    'recent',
#    'surg',
#    'price',
#    'also',
#    'concern',
#    'manufactur',
#    'hanov',
#    'futur',
#    'analyst',
#    'ralli',
#    'near',
#    'around',
#    'barrel',
#    'said',
#    'said',
#    'look',
#    'june',
#    'bond',
#    'contract',
#    'find',
#    'support',
#    'quit',
#    'readi',
#    'jump',
#    'bullish',
#    'bandwagon',
#    'juri',
#    'still',
#    'week',
#    'said']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['action', 'program', 'africa'],
#   'body': ['reagan',
#    'administr',
#    'respond',
#    'last',
#    'year',
#    'unit',
#    'nation',
#    'special',
#    'session',
#    'africa',
#    'today',
#    'outlin',
#    'action',
#    'program',
#    'africa',
#    'focus',
#    'heavili',
#    'econom',
#    'reform',
#    'white',
#    'hous',
#    'statement',
#    'announc',
#    'establish',
#    'goal',
#    'econom',
#    'program',
#    'polici',
#    'africa',
#    'hunger',
#    'region',
#    'econom',
#    'growth',
#    'polici',
#    'reform',
#    'privat',
#    'sector',
#    'develop',
#    'statement',
#    'said',
#    'program',
#    'action',
#    'recommend',
#    'white',
#    'hous',
#    'task',
#    'forc',
#    'last',
#    'septemb',
#    'seri',
#    'recommend',
#    'task',
#    'forc',
#    'call',
#    'effort',
#    'address',
#    'africa',
#    'heavi',
#    'debt',
#    'burden',
#    'said',
#    'food',
#    'stress',
#    'product',
#    'incent',
#    'reinforc',
#    'african',
#    'nation',
#    'econom',
#    'reform',
#    'product',
#    'also',
#    'said',
#    'better',
#    'african',
#    'access',
#    'world',
#    'market',
#    'promot',
#    'reward',
#    'good',
#    'perform',
#    'enabl',
#    'african',
#    'nation',
#    'earn',
#    'econom',
#    'growth',
#    'privat',
#    'sector',
#    'mobil',
#    'provid',
#    'privat',
#    'voluntari',
#    'corpor',
#    'involv',
#    'humanitarian',
#    'said',
#    'donor',
#    'countri',
#    'negoti',
#    'exist',
#    'intern',
#    'monetari',
#    'bank',
#    'coordin',
#    'process',
#    'framework',
#    'agreement',
#    'african',
#    'countri',
#    'establish',
#    'structur',
#    'adjust',
#    'reform',
#    'program',
#    'task',
#    'forc',
#    'call',
#    'separ',
#    'budget',
#    'account',
#    'bilater',
#    'order',
#    'focu',
#    'better',
#    'reward',
#    'econom',
#    'perform',
#    'increas',
#    'flexibl',
#    'assist',
#    'program',
#    'incent',
#    'econom',
#    'reform',
#    'privat',
#    'sector',
#    'develop']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['unusu', 'texa', 'instrument', 'prefer', 'price'],
#   'body': ['novel',
#    'type',
#    'financ',
#    'texa',
#    'instrument',
#    'market',
#    'issu',
#    'convert',
#    'money',
#    'market',
#    'prefer',
#    'stock',
#    'brother',
#    'sole',
#    'manag',
#    'origin',
#    'convert',
#    'concept',
#    'said',
#    'three',
#    'tranch',
#    'total',
#    'first',
#    'dividend',
#    'stock',
#    'strike',
#    'price',
#    'repres',
#    'premium',
#    'common',
#    'stock',
#    'price',
#    'term',
#    'also',
#    'includ',
#    'dividend',
#    'prefer',
#    'strike',
#    'price',
#    'premium',
#    'dividend',
#    'prefer',
#    'strike',
#    'price',
#    'premium',
#    'texa',
#    'instrument',
#    'common',
#    'close',
#    'manag',
#    'director',
#    'said',
#    'demand',
#    'offer',
#    'unbeliev',
#    'especi',
#    'first',
#    'tranch',
#    'said',
#    'origin',
#    'concept',
#    'auction',
#    'money',
#    'market',
#    'prefer',
#    'stock',
#    'three',
#    'year',
#    'convers',
#    'featur',
#    'issu',
#    'wrinkl',
#    'comment',
#    'first',
#    'tranch',
#    'note',
#    'origin',
#    'price',
#    'talk',
#    'call',
#    'dividend',
#    'four',
#    'area',
#    'gradual',
#    'intens',
#    'demand',
#    'save',
#    'issuer',
#    'money',
#    'financ',
#    'cost',
#    'offici',
#    'said',
#    'virtual',
#    'buyer',
#    'first',
#    'tranch',
#    'receiv',
#    'want',
#    'said',
#    'latter',
#    'tranch',
#    'strongli',
#    'oversubscrib',
#    'like',
#    'money',
#    'market',
#    'prefer',
#    'stock',
#    'version',
#    'allow',
#    'investor',
#    'redeem',
#    'hold',
#    'everi',
#    'seven',
#    'week',
#    'investor',
#    'maintain',
#    'hold',
#    'sell',
#    'offer',
#    'hold',
#    'secur',
#    'auction',
#    'dividend',
#    'least',
#    'level',
#    'specifi',
#    'advanc',
#    'said',
#    'secur',
#    'sold',
#    'broad',
#    'rang',
#    'investor',
#    'includ',
#    'major',
#    'insur',
#    'compani',
#    'bank',
#    'money',
#    'manag',
#    'pension',
#    'fund']},
#  {'topics': [],
#   'places': ['usa', 'canada'],
#   'title': ['clark', 'expect', 'action', 'acid', 'rain'],
#   'body': ['canadian',
#    'foreign',
#    'secretari',
#    'clark',
#    'wind',
#    'visit',
#    'washington',
#    'said',
#    'expect',
#    'reagan',
#    'administr',
#    'take',
#    'action',
#    'reduc',
#    'acid',
#    'rain',
#    'impress',
#    'movement',
#    'unit',
#    'state',
#    'administr',
#    'acid',
#    'rain',
#    'much',
#    'movement',
#    'cant',
#    'judg',
#    'predict',
#    'told',
#    'report',
#    'meet',
#    'american',
#    'offici',
#    'part',
#    'routin',
#    'consult',
#    'also',
#    'expect',
#    'groundwork',
#    'summit',
#    'ottawa',
#    'next',
#    'month',
#    'presid',
#    'reagan',
#    'prime',
#    'minist',
#    'clark',
#    'today',
#    'held',
#    'discuss',
#    'treasuri',
#    'secretari',
#    'jame',
#    'baker',
#    'democrat',
#    'patrick',
#    'moynihan',
#    'york',
#    'christoph',
#    'connecticut',
#    'lloyd',
#    'texa',
#    'georg',
#    'mitchel',
#    'main',
#    'yesterday',
#    'held',
#    'talk',
#    'vice',
#    'presid',
#    'georg',
#    'bush',
#    'secretari',
#    'state',
#    'georg',
#    'commerc',
#    'secretari',
#    'prioriti',
#    'canada',
#    'seek',
#    'evid',
#    'reagan',
#    'prepar',
#    'live',
#    'commit',
#    'made',
#    'last',
#    'year',
#    'implement',
#    'unit',
#    'state',
#    'billion',
#    'program',
#    'test',
#    'cleaner',
#    'burn',
#    'coal',
#    'issu',
#    'discuss',
#    'length',
#    'baker',
#    'sever',
#    'senat',
#    'includ',
#    'mitchel',
#    'canada',
#    'keep',
#    'heat',
#    'reagan',
#    'administr',
#    'forc',
#    'action',
#    'canadian',
#    'offici',
#    'said',
#    'also',
#    'taken',
#    'senat',
#    'baker',
#    'trade',
#    'issu',
#    'includ',
#    'need',
#    'unit',
#    'state',
#    'canada',
#    'establish',
#    'better',
#    'mechan',
#    'settl',
#    'trade',
#    'disput',
#    'countri',
#    'major',
#    'trade',
#    'partner',
#    'canadian',
#    'offici',
#    'said']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['ford', 'motor', 'distribut', 'profit', 'share'],
#   'body': ['ford',
#    'motor',
#    'said',
#    'check',
#    'distribut',
#    'employe',
#    'facil',
#    'distribut',
#    'averag',
#    'payment',
#    'employe',
#    'compar']},
#  {'topics': [],
#   'places': ['jamaica'],
#   'title': ['jamaica', 'borrow'],
#   'body': ['jamaica',
#    'billion',
#    'foreign',
#    'debt',
#    'reduc',
#    'oblig',
#    'year',
#    'prime',
#    'minist',
#    'edward',
#    'said',
#    'today',
#    'speak',
#    'news',
#    'confer',
#    'said',
#    'jamaica',
#    'reach',
#    'maximum',
#    'stock',
#    'debt',
#    'undertak',
#    'borrow',
#    'justifi',
#    'econom',
#    'growth',
#    'year',
#    'well',
#    'reduc',
#    'stock',
#    'debt',
#    'million',
#    'dollar',
#    'said',
#    'told',
#    'report',
#    'govern',
#    'reduc',
#    'jamaica',
#    'ratio',
#    'debt',
#    'payment',
#    'foreign',
#    'exchang',
#    'earn',
#    'current',
#    'within',
#    'three',
#    'year',
#    'debt',
#    'payment',
#    'year',
#    'expect',
#    'total',
#    'dollar',
#    'said',
#    'yesterday',
#    'jamaica',
#    'agre',
#    'creditor',
#    'bank',
#    'reschedul',
#    'next',
#    'year',
#    'accord',
#    'includ',
#    'grace',
#    'period',
#    'princip',
#    'payment',
#    'eight',
#    'half',
#    'year',
#    'reduct',
#    'interest',
#    'rate',
#    'last',
#    'week',
#    'jamaica',
#    'obtain',
#    'year',
#    'reschedul',
#    'princip',
#    'interest',
#    'dollar',
#    'debt',
#    'pari',
#    'club',
#    'nation',
#    'debt',
#    'fallen',
#    'next',
#    'year']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['faster', 'test', 'sickl', 'cell', 'anemia', 'develop'],
#   'body': ['team',
#    'california',
#    'research',
#    'said',
#    'develop',
#    'better',
#    'faster',
#    'test',
#    'detect',
#    'sickl',
#    'cell',
#    'anemia',
#    'unborn',
#    'child',
#    'exist',
#    'procedur',
#    'test',
#    'develop',
#    'cetu',
#    'corp',
#    'research',
#    'requir',
#    'small',
#    'amount',
#    'genet',
#    'materi',
#    'fetu',
#    'produc',
#    'diagnosi',
#    'within',
#    'unlik',
#    'test',
#    'requir',
#    'sever',
#    'done',
#    'special',
#    'center',
#    'said',
#    'sickl',
#    'cell',
#    'anemia',
#    'pain',
#    'inherit',
#    'blood',
#    'diseas',
#    'caus',
#    'blood',
#    'cell',
#    'stiffen',
#    'shape',
#    'primarili',
#    'found',
#    'black',
#    'research',
#    'said',
#    'england',
#    'journal',
#    'medicin',
#    'procedur',
#    'promis',
#    'rapid',
#    'sensit',
#    'reliabl',
#    'method',
#    'prenat',
#    'diagnosi',
#    'sickl',
#    'cell',
#    'diseas',
#    'addit',
#    'said',
#    'techniqu',
#    'might',
#    'also',
#    'adapt',
#    'detect',
#    'type',
#    'genet',
#    'diseas']},
#  {'topics': ['earn'],
#   'places': ['canada'],
#   'title': ['bank', 'british', 'columbia'],
#   'body': ['loss',
#    'profit',
#    'three',
#    'profit',
#    'profit',
#    'year',
#    'period',
#    'octob',
#    'loss',
#    'profit',
#    'loss',
#    'profit',
#    'asset',
#    'billion',
#    'billion',
#    'note',
#    'exclud',
#    'extraordinari',
#    'loss',
#    'exclud',
#    'extraordinari',
#    'loss',
#    'involv',
#    'cost',
#    'sale',
#    'bank',
#    'asset',
#    'bank',
#    'canada',
#    'eight',
#    'conting',
#    'liabil',
#    'respect',
#    'litig',
#    'potenti',
#    'reassess',
#    'defer',
#    'debit',
#    'bank',
#    'asset',
#    'sold',
#    'bank',
#    'canada',
#    'unit',
#    'shanghai',
#    'bank',
#    'corp',
#    'prefer']},
#  {'topics': [],
#   'places': ['usa', 'iran'],
#   'title': ['scandal', 'particip', 'immun', 'offer'],
#   'body': ['albert',
#    'hakim',
#    'merchant',
#    'first',
#    'player',
#    'iran',
#    'scandal',
#    'entic',
#    'testifi',
#    'promis',
#    'immun',
#    'investig',
#    'said',
#    'hous',
#    'select',
#    'committe',
#    'probe',
#    'iran',
#    'scandal',
#    'vote',
#    'grant',
#    'limit',
#    'immun',
#    'crimin',
#    'prosecut',
#    'hakim',
#    'return',
#    'testimoni',
#    'hakim',
#    'said',
#    'deepli',
#    'involv',
#    'start',
#    'attempt',
#    'trade',
#    'iran',
#    'help',
#    'free',
#    'american',
#    'hostag',
#    'lebanon',
#    'divers',
#    'fund',
#    'rebel',
#    'nicaragua']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['restaur', 'associ'],
#   'body': ['year',
#    'note',
#    'includ',
#    'loss',
#    'share',
#    'restat',
#    'give',
#    'effect',
#    'stock',
#    'split',
#    'form',
#    'class',
#    'dividend',
#    'august']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['michigan', 'gener', 'corp'],
#   'body': ['loss',
#    'loss',
#    'year',
#    'loss',
#    'loss',
#    'loss',
#    'note',
#    'year',
#    'loss',
#    'includ',
#    'respect',
#    'discontinu',
#    'year',
#    'includ',
#    'loss',
#    'respect']},
#  {'topics': ['crude', 'nat-gas', 'iron-steel'],
#   'places': ['usa', 'libya'],
#   'title': ['prove', 'reserv', 'fall'],
#   'body': ['corp',
#    'said',
#    'prove',
#    'reserv',
#    'natur',
#    'liquid',
#    'fell',
#    'barrel',
#    'billion',
#    'barrel',
#    'figur',
#    'annual',
#    'report',
#    'indic',
#    'much',
#    'drop',
#    'result',
#    'exclus',
#    'barrel',
#    'libyan',
#    'reserv',
#    'govern',
#    'last',
#    'june',
#    'direct',
#    'compani',
#    'libyan',
#    'oper',
#    'marathon',
#    'texa',
#    'corp',
#    'sale',
#    'billion',
#    'oper',
#    'total',
#    'sale',
#    'came',
#    'steel',
#    'unit',
#    'diversifi',
#    'busi',
#    'includ',
#    'oilfield',
#    'servic',
#    'materi',
#    'miner',
#    'chemic',
#    'real',
#    'estat',
#    'accord',
#    'report',
#    'domest',
#    'liquid',
#    'reserv',
#    'fell',
#    'slightli',
#    'barrel',
#    'foreign',
#    'reserv',
#    'fell',
#    'barrel',
#    'larg',
#    'drop',
#    'foreign',
#    'reserv',
#    'middl',
#    'east',
#    'africa',
#    'fell',
#    'barrel',
#    'reflect',
#    'exclus',
#    'libya',
#    'total',
#    'natur',
#    'reserv',
#    'fell',
#    'trillion',
#    'cubic',
#    'foot',
#    'trillion',
#    'drop',
#    'came',
#    'middl',
#    'east',
#    'africa',
#    'reserv',
#    'fell',
#    'zero',
#    'billion',
#    'cubic',
#    'foot',
#    'exclud',
#    'libyan',
#    'reserv',
#    'natur',
#    'reserv',
#    'fell',
#    'trillion',
#    'cubic',
#    'foot',
#    'trillion',
#    'foreign',
#    'reserv',
#    'fell',
#    'trillion',
#    'trillion',
#    'area',
#    'said',
#    'total',
#    'capit',
#    'spend',
#    'fell',
#    'billion',
#    'audit',
#    'figur',
#    'eight',
#    'higher',
#    'figur',
#    'compani',
#    'report',
#    'also',
#    'said',
#    'expect',
#    'record',
#    'gain',
#    'repres',
#    'previous',
#    'exist',
#    'invest',
#    'credit',
#    'allow',
#    'loss',
#    'half',
#    'credit',
#    'reflect',
#    'fourth',
#    'quarter',
#    'discuss',
#    'steel',
#    'result',
#    'said',
#    'plant',
#    'shut',
#    'last',
#    'month',
#    'previous',
#    'plant',
#    'perman',
#    'close',
#    'took',
#    'fourth',
#    'quarter',
#    'charg',
#    'billion',
#    'restructur',
#    'steel',
#    'oper',
#    'charg',
#    'includ',
#    'indefinit',
#    'last',
#    'month',
#    'four',
#    'plant',
#    'utah',
#    'pennsylvania',
#    'texa',
#    'plant',
#    'part',
#    'plant',
#    'pennsylvania',
#    'indiana',
#    'alabama',
#    'ohio',
#    'chicago',
#    'previous',
#    'oper',
#    'perman',
#    'shut',
#    'improv',
#    'market',
#    'condit',
#    'product',
#    'plant',
#    'make',
#    'feasibl',
#    'reopen',
#    'said',
#    'report',
#    'hand',
#    'lack',
#    'futur',
#    'market',
#    'improv',
#    'necessit',
#    'perman',
#    'close']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['stock', 'step', 'pare', 'debt'],
#   'body': ['petroleum',
#    'chairman',
#    'said',
#    'compani',
#    'stock',
#    'rank',
#    'fourth',
#    'activ',
#    'list',
#    'stock',
#    'trade',
#    'today',
#    'rose',
#    'partli',
#    'step',
#    'took',
#    'pare',
#    'debt',
#    'told',
#    'interview',
#    'today',
#    'part',
#    'strength',
#    'result',
#    'rise',
#    'price',
#    'also',
#    'analyst',
#    'happi',
#    'step',
#    'taken',
#    'pare',
#    'debt',
#    'stock',
#    'rose',
#    'share',
#    'follow',
#    'recommend',
#    'analyst',
#    'compani',
#    'sourc',
#    'said',
#    'debt',
#    'stood',
#    'billion',
#    'decemb',
#    'high',
#    'billion',
#    'analyst',
#    'said',
#    'share',
#    'price',
#    'closer',
#    'actual',
#    'price',
#    'said',
#    'analyst',
#    'right',
#    'price',
#    'rise',
#    'higher',
#    'seem',
#    'make',
#    'sens',
#    'howev',
#    'cautiou',
#    'strength',
#    'crude',
#    'price',
#    'expect',
#    'price',
#    'fluctuat',
#    'barrel',
#    'year',
#    'industri',
#    'analyst',
#    'said',
#    'reason',
#    'stock',
#    'popular',
#    'stock',
#    'trade',
#    'strong',
#    'discount',
#    'apprais',
#    'valu',
#    'attract',
#    'price',
#    'small',
#    'investor',
#    'charl',
#    'andrew',
#    'analyst',
#    'follow',
#    'john',
#    'greenwich',
#    'conn',
#    'said',
#    'apprais',
#    'valu',
#    'compani',
#    'base',
#    'avail',
#    'data',
#    'stock',
#    'trade',
#    'apprais',
#    'valu',
#    'compani',
#    'tremend',
#    'leverag',
#    'togeth',
#    'price',
#    'steadi',
#    'higher',
#    'good',
#    'room',
#    'improv',
#    'said',
#    'price',
#    'turn',
#    'lower',
#    'pressur',
#    'share',
#    'fell',
#    'eight',
#    'share',
#    'last',
#    'week',
#    'analyst',
#    'apprais',
#    'valu',
#    'compani',
#    'revis',
#    'asset',
#    'sale',
#    'reserv',
#    'told',
#    'asset',
#    'sale',
#    'amount',
#    'billion',
#    'complet',
#    'none',
#    'plan']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['michigan', 'gener', 'begin', 'exchang', 'offer'],
#   'body': ['michigan',
#    'gener',
#    'corp',
#    'said',
#    'began',
#    'exchang',
#    'offer',
#    'outstand',
#    'princip',
#    'amount',
#    'senior',
#    'subordin',
#    'debentur',
#    'decemb',
#    'pursuant',
#    'exchang',
#    'offer',
#    'princip',
#    'amount',
#    'receiv',
#    'princip',
#    'amount',
#    'senior',
#    'subordin',
#    'note',
#    'march',
#    'princip',
#    'amount',
#    'bear',
#    'convert',
#    'senior',
#    'note',
#    'march',
#    'share',
#    'delay',
#    'convert',
#    'prefer',
#    'stock',
#    'liquid',
#    'prefer',
#    'share',
#    'offer',
#    'expir',
#    'april',
#    'nine',
#    'michigan',
#    'gener',
#    'said',
#    'exchang',
#    'offer',
#    'crucial',
#    'attempt',
#    'restructur',
#    'reduc',
#    'risk',
#    'chapter',
#    'princip',
#    'purpos',
#    'offer',
#    'reduc',
#    'debt',
#    'servic',
#    'increas',
#    'stockhold',
#    'equiti',
#    'induc',
#    'lender',
#    'continu',
#    'fund',
#    'assum',
#    'accept',
#    'offer',
#    'michigan',
#    'annual',
#    'cash',
#    'interest',
#    'requir',
#    'reduc',
#    'said',
#    'complet',
#    'subject',
#    'tender',
#    'least',
#    'debentur',
#    'lender',
#    'waiv',
#    'default',
#    'loan',
#    'agreement']},
#  {'topics': ['earn'],
#   'places': ['canada'],
#   'title': ['bank', 'revis', 'share', 'estim'],
#   'body': ['bank',
#    'british',
#    'columbia',
#    'said',
#    'revis',
#    'estim',
#    'sharehold',
#    'distribut',
#    'last',
#    'novemb',
#    'sale',
#    'bank',
#    'asset',
#    'bank',
#    'canada',
#    'share',
#    'share',
#    'bank',
#    'said',
#    'estim',
#    'rise',
#    'share',
#    'full',
#    'pension',
#    'surplu',
#    'obtain',
#    'said',
#    'know',
#    'distribut',
#    'made',
#    'earlier',
#    'report',
#    'oper',
#    'profit',
#    'first',
#    'quarter',
#    'januari',
#    'fell',
#    'previou',
#    'year',
#    'octob',
#    'bank',
#    'post',
#    'oper',
#    'loss',
#    'profit',
#    'bank',
#    'also',
#    'post',
#    'extraordinari',
#    'loss',
#    'fiscal',
#    'bank',
#    'british',
#    'columbia',
#    'sold',
#    'asset',
#    'last',
#    'novemb',
#    'bank',
#    'canada',
#    'unit',
#    'shanghai',
#    'bank',
#    'corp',
#    'said',
#    'effort',
#    'wind',
#    'bank',
#    'affair',
#    'proceed',
#    'quickli',
#    'possibl',
#    'bank',
#    'said',
#    'expect',
#    'report',
#    'posit',
#    'earn',
#    'futur',
#    'period',
#    'unforeseen',
#    'circumst',
#    'loan',
#    'loss',
#    'bank',
#    'previous',
#    'said',
#    'figur',
#    'move',
#    'sell',
#    'asset',
#    'rose',
#    'fiscal',
#    'bank',
#    'said',
#    'total',
#    'repres',
#    'downward',
#    'adjust',
#    'portfolio',
#    'syndic',
#    'sovereign',
#    'risk',
#    'loan',
#    'requir',
#    'sale',
#    'bank',
#    'novemb',
#    'bank',
#    'confin',
#    'activ',
#    'wind',
#    'affair',
#    'bank',
#    'british',
#    'columbia',
#    'said']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['hous', 'vote', 'block', 'contra', 'month'],
#   'body': ['hous',
#    'vote',
#    'block',
#    'militari',
#    'nicaraguan',
#    'rebel',
#    'presid',
#    'reagan',
#    'account',
#    'past',
#    'assist',
#    'includ',
#    'money',
#    'divert',
#    'sale',
#    'iran',
#    'vote',
#    'seen',
#    'temporari',
#    'defeat',
#    'reagan',
#    'made',
#    'contra',
#    'initi',
#    'congression',
#    'democrat',
#    'leader',
#    'conced',
#    'despit',
#    'today',
#    'vote',
#    'muster',
#    'major',
#    'overrid',
#    'certain',
#    'reagan',
#    'veto',
#    'said',
#    'like',
#    'battl',
#    'expect',
#    'fall',
#    'reagan',
#    'request']},
#  {'topics': ['earn'],
#   'places': ['canada'],
#   'title': ['gold', 'mine'],
#   'body': ['year']},
#  {'topics': ['carcass', 'livestock'],
#   'places': ['argentina'],
#   'title': ['argentin', 'meat', 'export', 'higher'],
#   'body': ['argentin',
#    'meat',
#    'export',
#    'total',
#    'tonn',
#    'tonn',
#    'ship',
#    'period',
#    'nation',
#    'meat',
#    'board',
#    'said',
#    'shipment',
#    'tonn',
#    'compar',
#    'figur',
#    'period',
#    'bracket',
#    'includ',
#    'beef',
#    'hors',
#    'meat',
#    'beef',
#    'offal',
#    'argentin',
#    'meat',
#    'export',
#    'total',
#    'tonn',
#    'februari',
#    'tonn',
#    'ship',
#    'month',
#    'shipment',
#    'tonn',
#    'compar',
#    'figur',
#    'februari',
#    'bracket',
#    'includ',
#    'beef',
#    'hors',
#    'meat',
#    'beef',
#    'offal',
#    'board',
#    'main',
#    'destin',
#    'refriger',
#    'beef',
#    'bone',
#    'equival',
#    'follow',
#    'tonn',
#    'compar',
#    'figur',
#    'bracket',
#    'brazil',
#    'unavail',
#    'israel',
#    'peru',
#    'singapor',
#    'switzerland',
#    'canari',
#    'island',
#    'malta',
#    'chile',
#    'main',
#    'destin',
#    'meat',
#    'cook',
#    'beef',
#    'bone',
#    'equival',
#    'tonn',
#    'compar',
#    'figur',
#    'bracket',
#    'unit',
#    'state']},
#  {'topics': ['earn'],
#   'places': ['canada'],
#   'title': ['plan', 'stock', 'split'],
#   'body': ['gold',
#    'mine',
#    'said',
#    'plan',
#    'common',
#    'stock',
#    'split',
#    'pend',
#    'sharehold',
#    'approv',
#    'april',
#    'said',
#    'approv',
#    'requir',
#    'vote',
#    'cast',
#    'said',
#    'campbel',
#    'lake',
#    'mine',
#    'expect',
#    'vote',
#    'favor',
#    'split']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['vanzetti', 'increas', 'share', 'approv'],
#   'body': ['vanzetti',
#    'system',
#    'said',
#    'sharehold',
#    'approv',
#    'increas',
#    'number',
#    'author',
#    'share',
#    'five',
#    'three',
#    'sharehold',
#    'also',
#    'approv',
#    'increas',
#    'number',
#    'share',
#    'reserv',
#    'option',
#    'employe']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['furnitur', 'corp', 'dividend'],
#   'body': ['four', 'four', 'prior', 'april', 'record', 'march']},
#  {'topics': ['trade'],
#   'places': ['usa'],
#   'title': ['hous', 'panel', 'take', 'first', 'trade', 'bill', 'vote'],
#   'body': ['hous',
#    'trade',
#    'lawmak',
#    'took',
#    'first',
#    'vote',
#    'measur',
#    'design',
#    'toughen',
#    'trade',
#    'held',
#    'tomorrow',
#    'difficult',
#    'vote',
#    'controversi',
#    'plan',
#    'protect',
#    'american',
#    'industri',
#    'meet',
#    'close',
#    'session',
#    'hous',
#    'mean',
#    'trade',
#    'subcommitte',
#    'fail',
#    'resolv',
#    'sensit',
#    'issu',
#    'forc',
#    'major',
#    'foreign',
#    'trade',
#    'partner',
#    'sever',
#    'trade',
#    'surplu',
#    'unit',
#    'state',
#    'subcommitte',
#    'consid',
#    'version',
#    'trade',
#    'legisl',
#    'open',
#    'foreign',
#    'market',
#    'drop',
#    'last',
#    'year',
#    'effort',
#    'forc',
#    'presid',
#    'reagan',
#    'retali',
#    'quota',
#    'tariff',
#    'congression',
#    'identifi',
#    'said',
#    'lawmak',
#    'intend',
#    'wrap',
#    'propos',
#    'tomorrow',
#    'consid',
#    'propos',
#    'mandat',
#    'retali',
#    'specif',
#    'trade',
#    'penalti',
#    'legisl',
#    'face',
#    'anoth',
#    'hurdl',
#    'full',
#    'mean',
#    'committe',
#    'next',
#    'week',
#    'full',
#    'hous',
#    'vote',
#    'missouri',
#    'democrat',
#    'seek',
#    'parti',
#    'presidenti',
#    'nomin',
#    'said',
#    'offer',
#    'amend',
#    'call',
#    'reduct',
#    'trade',
#    'surplu',
#    'countri',
#    'barrier',
#    'import',
#    'good',
#    'moder',
#    'version',
#    'earlier',
#    'plan',
#    'forc',
#    'mandatori',
#    'cent',
#    'annual',
#    'trade',
#    'surplu',
#    'unit',
#    'state',
#    'japan',
#    'south',
#    'korea',
#    'taiwan',
#    'west',
#    'germani',
#    'countri',
#    'largest',
#    'trade',
#    'imbal',
#    'criterion',
#    'good',
#    'amend',
#    'standard',
#    'trade',
#    'deficit',
#    'told',
#    'report',
#    'trade',
#    'chang',
#    'becom',
#    'part',
#    'major',
#    'congression',
#    'administr',
#    'effort',
#    'turn',
#    'around',
#    'record',
#    'trade',
#    'deficit',
#    'billion',
#    'last',
#    'year',
#    'open',
#    'foreign',
#    'market',
#    'make',
#    'product',
#    'competit',
#    'hous',
#    'speaker',
#    'jame',
#    'wright',
#    'texa',
#    'democrat',
#    'said',
#    'today',
#    'expect',
#    'full',
#    'hous',
#    'approv',
#    'trade',
#    'bill',
#    'reagan',
#    'accept',
#    'final',
#    'congression',
#    'bill',
#    'expect',
#    'whatev',
#    'report',
#    'mean',
#    'committe',
#    'good',
#    'bill',
#    'effect',
#    'bill',
#    'told',
#    'report',
#    'comprehens',
#    'trade',
#    'bill',
#    'includ',
#    'work',
#    'committe',
#    'export',
#    'control',
#    'high',
#    'technolog',
#    'worker',
#    'displac',
#    'foreign',
#    'competit',
#    'stimul',
#    'research',
#    'develop',
#    'remov',
#    'foreign',
#    'trade',
#    'barrier',
#    'improv',
#    'educ',
#    'worker',
#    'train',
#    'lawmak',
#    'agre',
#    'first',
#    'time',
#    'industri',
#    'charg',
#    'foreign',
#    'produc',
#    'unfair',
#    'competit',
#    'deni',
#    'basic',
#    'worker',
#    'right',
#    'collect',
#    'bargain',
#    'safeti',
#    'rule',
#    'payment',
#    'minimum',
#    'wage',
#    'appropri',
#    'countri',
#    'econom',
#    'develop',
#    'transfer',
#    'trade',
#    'repres',
#    'power',
#    'held',
#    'reagan',
#    'decid',
#    'retali',
#    'foreign',
#    'violat',
#    'fair',
#    'trade',
#    'rule',
#    'injur',
#    'industri',
#    'deserv',
#    'import',
#    'relief',
#    'agre',
#    'make',
#    'easier',
#    'compani',
#    'temporari',
#    'relief',
#    'import',
#    'competit',
#    'agre',
#    'industri',
#    'provid',
#    'plan',
#    'becom',
#    'competit',
#    'administr',
#    'announc',
#    'support',
#    'said',
#    'yesterday',
#    'cautious',
#    'optimist',
#    'hous',
#    'come',
#    'accept',
#    'bill']},
#  {'topics': ['trade'],
#   'places': ['france', 'ussr'],
#   'title': ['soviet', 'minist', 'trade', 'boost', 'french'],
#   'body': ['soviet',
#    'first',
#    'deputi',
#    'prime',
#    'minist',
#    'said',
#    'brief',
#    'visit',
#    'countri',
#    'want',
#    'boost',
#    'joint',
#    'busi',
#    'franc',
#    'reduct',
#    'franc',
#    'trade',
#    'deficit',
#    'soviet',
#    'union',
#    'depend',
#    'french',
#    'also',
#    'chairman',
#    'state',
#    'committe',
#    'told',
#    'news',
#    'confer',
#    'discuss',
#    'varieti',
#    'possibl',
#    'deal',
#    'french',
#    'compani',
#    'declin',
#    'figur',
#    'possibl',
#    'contract',
#    'said',
#    'discuss',
#    'plant',
#    'protect',
#    'process',
#    'highli',
#    'sulphur',
#    'packag',
#    'technolog',
#    'agricultur',
#    'product',
#    'fruit',
#    'veget',
#    'juic',
#    'process',
#    'offici',
#    'said',
#    'agreement',
#    'intent',
#    'packag',
#    'sign',
#    'soon',
#    'give',
#    'detail',
#    'compani',
#    'immedi',
#    'avail',
#    'comment',
#    'foresaw',
#    'reduct',
#    'year',
#    'franc',
#    'trade',
#    'shortfal',
#    'billion',
#    'franc',
#    'first',
#    'month',
#    'billion',
#    'whole',
#    'told',
#    'depend',
#    'franc',
#    'meet',
#    'pari',
#    'last',
#    'januari',
#    'french',
#    'soviet',
#    'foreign',
#    'trade',
#    'minist',
#    'said',
#    'commit',
#    'increas',
#    'effort',
#    'reduc',
#    'deficit',
#    'estim',
#    'time',
#    'show',
#    'french',
#    'franc',
#    'surplu',
#    'decemb',
#    'said',
#    'soviet',
#    'union',
#    'prepar',
#    'talk',
#    'interest',
#    'propos',
#    'offer',
#    'latest',
#    'technolog',
#    'assur',
#    'mutual',
#    'advantag',
#    'said',
#    'soviet',
#    'union',
#    'mani',
#    'task',
#    'ahead',
#    'deal',
#    'rapidli',
#    'propos',
#    'consid',
#    'interest',
#    'encourag',
#    'compani',
#    'take',
#    'advantag',
#    'guarante',
#    'interest',
#    'foreign',
#    'partner',
#    'joint',
#    'ventur',
#    'said',
#    'agreement',
#    'finalis',
#    'joint',
#    'ventur',
#    'said',
#    'concret',
#    'deal',
#    'finalis',
#    'result',
#    'billion',
#    'dollar',
#    'accord',
#    'sign',
#    'moscow',
#    'last',
#    'month',
#    'french',
#    'businessman',
#    'said',
#    'compani',
#    'prepar',
#    'propos',
#    'examin',
#    'soviet',
#    'union',
#    'last',
#    'month',
#    'said',
#    'agreement',
#    'exchang',
#    'billion',
#    'dollar',
#    'worth',
#    'good',
#    'said',
#    'agreement',
#    'intent',
#    'design',
#    'primarili',
#    'renew',
#    'increas',
#    'soviet',
#    'union',
#    'food',
#    'product',
#    'capac']},
#  {'topics': ['crude'],
#   'places': ['ecuador', 'venezuela'],
#   'title': ['venezuela', 'lend', 'ecuador', 'export'],
#   'body': ['venezuela',
#    'suppli',
#    'ecuador',
#    'undetermin',
#    'amount',
#    'crude',
#    'help',
#    'meet',
#    'export',
#    'commit',
#    'serious',
#    'affect',
#    'last',
#    'week',
#    'earthquak',
#    'energi',
#    'mine',
#    'minist',
#    'said',
#    'gave',
#    'detail',
#    'deal',
#    'said',
#    'crude',
#    'loan',
#    'agreement',
#    'made',
#    'state',
#    'compani',
#    'venezuela',
#    'ecuador',
#    'ecuador',
#    'forc',
#    'suspend',
#    'export',
#    'expect',
#    'four',
#    'month',
#    'earthquak',
#    'damag',
#    'pipelin',
#    'account',
#    'cent',
#    'export',
#    'incom',
#    'speak',
#    'report',
#    'palac',
#    'result',
#    'talk',
#    'ecuador',
#    'deputi',
#    'energi',
#    'minist',
#    'santo',
#    'arriv',
#    'last',
#    'night',
#    'volum',
#    'lent',
#    'ecuador',
#    'discount',
#    'opec',
#    'quota',
#    'affect',
#    'venezuela',
#    'said',
#    'august',
#    'produc',
#    'quota',
#    'sell',
#    'addit',
#    'amount',
#    'ecuador',
#    'repay',
#    'said',
#    'elabor',
#    'quota',
#    'arrang',
#    'ecuador',
#    'notifi',
#    'opec',
#    'telex',
#    'venezuela',
#    'lend',
#    'certain',
#    'amount',
#    'mani',
#    'venezuela',
#    'opec',
#    'output',
#    'quota',
#    'current',
#    'million',
#    'barrel',
#    'ecuador']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['eagl', 'cloth'],
#   'body': ['profit',
#    'profit',
#    'profit',
#    'profit',
#    'month',
#    'profit',
#    'loss',
#    'profit',
#    'loss',
#    'note',
#    'month',
#    'includ',
#    'increas',
#    'provis',
#    'doubt',
#    'account',
#    'share',
#    'give',
#    'effect',
#    'issuanc',
#    'share',
#    'exchang',
#    'outstand',
#    'seri',
#    'prefer',
#    'share']},
#  {'topics': [],
#   'places': ['iran', 'iraq'],
#   'title': ['iraq', 'iran', 'attack', 'repuls', 'southern', 'front'],
#   'body': ['iraq',
#    'said',
#    'repel',
#    'iranian',
#    'attack',
#    'posit',
#    'held',
#    'fourth',
#    'armi',
#    'corp',
#    'east',
#    'southern',
#    'iraqi',
#    'town',
#    'highway',
#    'baghdad',
#    'communiqu',
#    'said',
#    'iranian',
#    'infantri',
#    'brigad',
#    'back',
#    'tank',
#    'launch',
#    'overnight',
#    'attack',
#    'fierc',
#    'fight',
#    'rage',
#    'hour',
#    'iranian',
#    'troop',
#    'fled',
#    'battlefield',
#    'leav',
#    'kill',
#    'mani',
#    'wound',
#    'major',
#    'battl',
#    'report',
#    'fought',
#    'fourth',
#    'armi',
#    'corp',
#    'year',
#    'area',
#    'mainli',
#    'swampland',
#    'marsh',
#    'eastward',
#    'southern',
#    'port',
#    'citi',
#    'basra']},
#  {'topics': ['trade'],
#   'places': ['uk', 'japan'],
#   'title': ['britain', 'call', 'japan', 'increas', 'import'],
#   'body': ['britain',
#    'today',
#    'call',
#    'japan',
#    'increas',
#    'foreign',
#    'import',
#    'risk',
#    'rise',
#    'protection',
#    'harm',
#    'bring',
#    'trade',
#    'nation',
#    'british',
#    'trade',
#    'industri',
#    'secretari',
#    'paul',
#    'said',
#    'japan',
#    'must',
#    'heed',
#    'report',
#    'issu',
#    'japanes',
#    'govern',
#    'advisori',
#    'bodi',
#    'decemb',
#    'call',
#    'faster',
#    'domest',
#    'demand',
#    'help',
#    'trade',
#    'surplu',
#    'restructur',
#    'economi',
#    'recognis',
#    'strong',
#    'brought',
#    'problem',
#    'japan',
#    'domest',
#    'economi',
#    'told',
#    'group',
#    'japanes',
#    'businessmen',
#    'london',
#    'short',
#    'term',
#    'difficulti',
#    'allow',
#    'deflect',
#    'japan',
#    'fundament',
#    'reform',
#    'necessari',
#    'said',
#    'domest',
#    'issu',
#    'japan',
#    'import',
#    'propens',
#    'expand',
#    'soon',
#    'real',
#    'risk',
#    'protectionist',
#    'lobbi',
#    'particularli',
#    'japan',
#    'massiv',
#    'surplu',
#    'said',
#    'well',
#    'succeed',
#    'secur',
#    'action',
#    'govern',
#    'highli',
#    'injuri',
#    'trade',
#    'nation',
#    'like',
#    'japan',
#    'said',
#    'substanti',
#    'growth',
#    'volum',
#    'trade',
#    'japan',
#    'britain',
#    'amount',
#    'billion',
#    'sterl',
#    'billion',
#    'last',
#    'year',
#    'regrett',
#    'much',
#    'direct',
#    'japanes',
#    'sell',
#    'billion',
#    'sterl',
#    'billion',
#    'sold']},
#  {'topics': ['acq'],
#   'places': [],
#   'title': ['taft',
#    'broadcast',
#    'reject',
#    'share',
#    'buyout',
#    'offer',
#    'theta',
#    'corp'],
#   'body': []},
#  {'topics': ['acq'],
#   'places': ['usa'],
#   'title': ['taft', 'reject', 'offer'],
#   'body': ['taft',
#    'said',
#    'board',
#    'director',
#    'unanim',
#    'decid',
#    'accept',
#    'pend',
#    'propos',
#    'theta',
#    'corp',
#    'investor',
#    'group',
#    'taft',
#    'decis',
#    'base',
#    'thing',
#    'advis',
#    'financi',
#    'advisor',
#    'goldman',
#    'offer',
#    'share',
#    'inadequ',
#    'taft',
#    'said',
#    'board',
#    'conclud',
#    'offer',
#    'fail',
#    'recogn',
#    'fulli',
#    'futur',
#    'compani',
#    'direct',
#    'manag',
#    'explor',
#    'altern',
#    'includ',
#    'possibl',
#    'financi',
#    'restructur']},
#  {'topics': [],
#   'places': ['ecuador'],
#   'title': ['ecuador', 'debt', 'honour', 'quak', 'surviv'],
#   'body': ['ecuador',
#    'stricken',
#    'sever',
#    'earthquak',
#    'honour',
#    'billion',
#    'foreign',
#    'debt',
#    'ensur',
#    'surviv',
#    'countri',
#    'tremor',
#    'claim',
#    'least',
#    'life',
#    'caus',
#    'person',
#    'disappear',
#    'govern',
#    'posit',
#    'permit',
#    'honour',
#    'debt',
#    'commit',
#    'sacrif',
#    'countri',
#    'first',
#    'surviv',
#    'later',
#    'compli',
#    'inform',
#    'minist',
#    'told',
#    'said',
#    'nation',
#    'later',
#    'announc',
#    'definit',
#    'measur',
#    'foreign',
#    'debt',
#    'aftermath',
#    'earthquak',
#    'govern',
#    'said',
#    'caus',
#    'nearli',
#    'billion',
#    'econom',
#    'loss']},
#  {'topics': ['veg-oil'],
#   'places': ['uk'],
#   'title': ['british', 'minist', 'criticis', 'propos'],
#   'body': ['british',
#    'minist',
#    'said',
#    'propos',
#    'european',
#    'commun',
#    'veget',
#    'rais',
#    'price',
#    'fish',
#    'chip',
#    'pledg',
#    'govern',
#    'fight',
#    'lord',
#    'junior',
#    'agricultur',
#    'minist',
#    'told',
#    'hous',
#    'lord',
#    'rais',
#    'price',
#    'materi',
#    'mani',
#    'process',
#    'food',
#    'said',
#    'revenu',
#    'rais',
#    'consum',
#    'call',
#    'propos',
#    'repugn']},
#  {'topics': ['jobs'],
#   'places': ['australia'],
#   'title': ['australian', 'unemploy', 'februari'],
#   'body': ['australia',
#    'unemploy',
#    'rate',
#    'estim',
#    'workforc',
#    'februari',
#    'januari',
#    'compar',
#    'year',
#    'earlier',
#    'statist',
#    'bureau',
#    'said',
#    'number',
#    'unemploy',
#    'declin',
#    'januari',
#    'februari',
#    'said',
#    'unadjust',
#    'number',
#    'jobless',
#    'rose',
#    'workforc',
#    'januari',
#    'year',
#    'earlier']},
#  {'topics': [],
#   'places': ['ecuador'],
#   'title': ['ecuador', 'seek', 'halt', 'payment', 'bank'],
#   'body': ['ecuador',
#    'stricken',
#    'sever',
#    'earthquak',
#    'seek',
#    'negoti',
#    'privat',
#    'foreign',
#    'bank',
#    'postpon',
#    'payment',
#    'rest',
#    'year',
#    'financ',
#    'minist',
#    'domingo',
#    'said',
#    'said',
#    'statement',
#    'idea',
#    'foreign',
#    'bank',
#    'obtain',
#    'best',
#    'term',
#    'give',
#    'economi',
#    'complet',
#    'relief',
#    'period',
#    'deferr',
#    'payment',
#    'foreign',
#    'debt',
#    'present',
#    'year',
#    'statement',
#    'refer',
#    'payment',
#    'privat',
#    'foreign',
#    'bank',
#    'senior',
#    'govern',
#    'financ',
#    'offici',
#    'told',
#    'creditor',
#    'hold',
#    'ecuador',
#    'foreign',
#    'debt',
#    'total',
#    'billion',
#    'refer',
#    'debt',
#    'matur',
#    'foreign',
#    'govern',
#    'multilater',
#    'lend',
#    'agenc',
#    'account',
#    'remaind',
#    'ecuador',
#    'foreign',
#    'debt',
#    'offici',
#    'said',
#    'said',
#    'ecuador',
#    'privat',
#    'foreign',
#    'bank',
#    'interest',
#    'payment',
#    'rest',
#    'princip',
#    'payment',
#    'matur',
#    'year',
#    'said',
#    'ecuador',
#    'seek',
#    'loan',
#    'multilater',
#    'organis',
#    'world',
#    'bank',
#    'mission',
#    'soon',
#    'evalu',
#    'emerg',
#    'loan',
#    'govern',
#    'offici',
#    'said',
#    'ecuador',
#    'also',
#    'appeal',
#    'emerg',
#    'foreign',
#    'govern',
#    'govern',
#    'offici',
#    'calcul',
#    'loss',
#    'budget',
#    'last',
#    'thursday',
#    'earthquak',
#    'ecuador',
#    'total',
#    'servic',
#    'foreign',
#    'debt',
#    'creditor',
#    'quak',
#    'ruptur',
#    'ecuador',
#    'main',
#    'pipelin',
#    'suspend',
#    'crude',
#    'export',
#    'five',
#    'month',
#    'line',
#    'repair',
#    'account',
#    'total',
#    'export',
#    'total',
#    'revenu',
#    'tremor',
#    'ecuador',
#    'suspend',
#    'interest',
#    'payment',
#    'januari',
#    'privat',
#    'foreign',
#    'bank',
#    'offici',
#    'said',
#    'stop',
#    'interest',
#    'payment',
#    'squeez',
#    'stem',
#    'slide',
#    'world',
#    'price',
#    'export',
#    'billion',
#    'financ',
#    'offici',
#    'telephon',
#    'contact',
#    'everi',
#    'week',
#    'bank',
#    'bank',
#    'advisori',
#    'committe',
#    'senior',
#    'govern',
#    'financ',
#    'offici',
#    'said',
#    'committe',
#    'repres',
#    'countri',
#    'privat',
#    'foreign',
#    'bank',
#    'creditor',
#    'also',
#    'said',
#    'statement',
#    'bank',
#    'perceiv',
#    'imposs',
#    'moment',
#    'compli',
#    'ecuador',
#    'must',
#    'make',
#    'propos',
#    'line',
#    'realiti',
#    'earthquak',
#    'seek',
#    'better',
#    'option',
#    'defer',
#    'soften',
#    'negoti',
#    'condit',
#    'interest',
#    'payment',
#    'fall',
#    'least',
#    'monthli',
#    'privat',
#    'foreign',
#    'bank',
#    'ecuador',
#    'initi',
#    'propos',
#    'earlier',
#    'year',
#    'make',
#    'semiannu',
#    'annual',
#    'interest',
#    'payment',
#    'year',
#    'propos',
#    'sought',
#    'defer',
#    'interest',
#    'payment',
#    'june',
#    'earliest',
#    'foreign',
#    'banker',
#    'govern',
#    'offici',
#    'said',
#    'offici',
#    'held',
#    'last',
#    'formal',
#    'meet',
#    'advisori',
#    'committe',
#    'york',
#    'januari',
#    'negoti',
#    'suspend',
#    'januari',
#    'hour',
#    'kidnap',
#    'presid',
#    'leon',
#    'forc',
#    'paratroop',
#    'cross',
#    'least',
#    'peopl',
#    'least',
#    'miss',
#    'earthquak']},
#  {'topics': ['money-fx'],
#   'places': ['usa'],
#   'title': ['treasuri', 'secretari', 'baker', 'declin', 'comment'],
#   'body': ['treasuri',
#    'secretari',
#    'jame',
#    'baker',
#    'declin',
#    'comment',
#    'februari',
#    'pari',
#    'accord',
#    'major',
#    'industri',
#    'nation',
#    'agre',
#    'foster',
#    'exchang',
#    'rate',
#    'stabil',
#    'report',
#    'speech',
#    'nation',
#    'foundat',
#    'banquet',
#    'currenc',
#    'intervent',
#    'level',
#    'pari',
#    'baker',
#    'repli',
#    'never',
#    'talk',
#    'intervent',
#    'baker',
#    'also',
#    'declin',
#    'comment',
#    'view',
#    'foreign',
#    'exchang',
#    'market',
#    'reaction',
#    'accord']},
#  {'topics': ['crude'],
#   'places': ['venezuela', 'ecuador'],
#   'title': ['ecuador', 'opec', 'rais', 'export', 'quota'],
#   'body': ['ecuador',
#    'opec',
#    'rais',
#    'export',
#    'quota',
#    'barrel',
#    'compens',
#    'lost',
#    'output',
#    'last',
#    'week',
#    'earthquak',
#    'deputi',
#    'energi',
#    'minist',
#    'santo',
#    'said',
#    'santo',
#    'arriv',
#    'caraca',
#    'last',
#    'night',
#    'discu',
#    'plan',
#    'ecuador',
#    'organis',
#    'petroleum',
#    'export',
#    'countri',
#    'opec',
#    'approach',
#    'addit',
#    'output',
#    'relat',
#    'plan',
#    'discuss',
#    'venezuela',
#    'mexico',
#    'lend',
#    'ecuador',
#    'crude',
#    'repair',
#    'pipelin',
#    'damag',
#    'quak',
#    'earlier',
#    'venezuelan',
#    'energi',
#    'mine',
#    'minist',
#    'said',
#    'countri',
#    'suppli',
#    'unspecifi',
#    'part',
#    'ecuador',
#    'export',
#    'commit',
#    'santo',
#    'told',
#    'report',
#    'hope',
#    'first',
#    'cargo',
#    'barrel',
#    'leav',
#    'maracaibo',
#    'weekend',
#    'suppli',
#    'refineri',
#    'near',
#    'guayaquil',
#    'ecuador',
#    'also',
#    'want',
#    'make',
#    'ship',
#    'caribbean',
#    'destin',
#    'mexico',
#    'might',
#    'suppli',
#    'ecuador',
#    'south',
#    'korean',
#    'market',
#    'ecuador',
#    'unabl',
#    'export',
#    'five',
#    'month',
#    'extens',
#    'damag',
#    'mile',
#    'stretch',
#    'pipelin',
#    'link',
#    'jungl',
#    'oilfield',
#    'pacif',
#    'port']},
#  {'topics': ['oilseed', 'rapeseed'],
#   'places': ['china'],
#   'title': ['china', 'rapese', 'crop', 'damag', 'storm'],
#   'body': ['yield',
#    'hectar',
#    'rapese',
#    'central',
#    'china',
#    'hailstorm',
#    'tornado',
#    'swept',
#    'across',
#    'nearli',
#    'crop',
#    'march',
#    'china',
#    'news',
#    'agenc',
#    'said',
#    'today',
#    'storm',
#    'lash',
#    'yangtz',
#    'river',
#    'eastern',
#    'provinc',
#    'left',
#    'peopl',
#    'dead',
#    'injur',
#    'hous',
#    'flatten',
#    'boat',
#    'sunk',
#    'said',
#    'provinci',
#    'govern',
#    'sent',
#    'emerg',
#    'relief',
#    'counti',
#    'affect',
#    'news',
#    'agenc',
#    'said']},
#  {'topics': ['crude'],
#   'places': ['china'],
#   'title': ['china', 'close', 'second', 'round', 'offshor'],
#   'body': ['china',
#    'close',
#    'second',
#    'round',
#    'foreign',
#    'firm',
#    'offshor',
#    'explor',
#    'right',
#    'china',
#    'daili',
#    'report',
#    'quot',
#    'spokesman',
#    'china',
#    'nation',
#    'offshor',
#    'corp',
#    'china',
#    'sign',
#    'eight',
#    'contract',
#    'foreign',
#    'firm',
#    'block',
#    'pearl',
#    'river',
#    'mouth',
#    'south',
#    'yellow',
#    'cover',
#    'total',
#    'area',
#    'second',
#    'round',
#    'began',
#    'well',
#    'produc',
#    'result',
#    'southeast',
#    'output',
#    'barrel',
#    'well',
#    'drill',
#    'group',
#    'japanes',
#    'compani',
#    'spokesman',
#    'readi',
#    'enter',
#    'contract',
#    'offshor',
#    'block',
#    'third',
#    'round',
#    'began',
#    'contract',
#    'bound',
#    'restrict',
#    'impos',
#    'second',
#    'round',
#    'china',
#    'sign',
#    'contract',
#    'agreement',
#    'compani',
#    'countri',
#    'offshor',
#    'explor',
#    'open',
#    'foreign',
#    'eleven',
#    'contract',
#    'termin',
#    'discov',
#    'foreign',
#    'firm',
#    'invest',
#    'billion',
#    'offshor',
#    'china']},
#  {'topics': [],
#   'places': ['japan'],
#   'title': ['japan', 'relax', 'rule', 'secur', 'compani', 'outlet'],
#   'body': ['japan',
#    'relax',
#    'limit',
#    'establish',
#    'secur',
#    'compani',
#    'outlet',
#    'order',
#    'servic',
#    'grow',
#    'number',
#    'individu',
#    'investor',
#    'financ',
#    'ministri',
# ...
#    'detail',
#    'redempt',
#    'later',
#    'compani',
#    'stock',
#    'halt',
#    'trade',
#    'nyse']},
#  {'topics': ['acq'],
#   'places': ['usa'],
#   'title': ['arco', 'sell', 'oper'],
#   'body': ['atlant',
#    'said',
#    'sold',
#    'plan',
#    'cell',
#    'research',
#    'institut',
#    'unit',
#    'arco',
#    'seed',
#    'oper',
#    'transact',
#    'undisclos',
#    'price',
#    'compani',
#    'said',
#    'sold',
#    'dublin',
#    'plant',
#    'cell',
#    'research',
#    'milan',
#    'itali',
#    'arco',
#    'seed',
#    'genet',
#    'calif',
#    'atlant',
#    'said',
#    'divestitur',
#    'line',
#    'polici',
#    'focus',
#    'resourc',
#    'chemic',
#    'coal',
#    'oper']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['comment', 'justic', 'propos'],
#   'body': ['corp',
#    'said',
#    'support',
#    'recommend',
#    'depart',
#    'justic',
#    'allow',
#    'region',
#    'bell',
#    'compani',
#    'enter',
#    'busi',
#    'reject',
#    'govern',
#    'propos',
#    'compani',
#    'offer',
#    'long',
#    'distanc',
#    'servic',
#    'vigor',
#    'competitor',
#    'mani',
#    'telecommun',
#    'busi',
#    'support',
#    'effort',
#    'polici',
#    'maker',
#    'preserv',
#    'promot',
#    'fair',
#    'opportun',
#    'competit',
#    'said',
#    'comment',
#    'file',
#    'district',
#    'court',
#    'overse',
#    'regul',
#    'bell',
#    'compani',
#    'compani',
#    'entri',
#    'region',
#    'bell',
#    'compani',
#    'long',
#    'market',
#    'back',
#    'progress',
#    'truli',
#    'competit',
#    'environ',
#    'occur',
#    'largest',
#    'independ',
#    'telephon',
#    'system',
#    'countri',
#    'manufactur',
#    'telecommun',
#    'equip',
#    'joint',
#    'ventur',
#    'japan',
#    'siemen',
#    'west',
#    'germani',
#    'also',
#    'hold',
#    'stake',
#    'sprint',
#    'commun',
#    'long',
#    'distanc',
#    'carrier',
#    'countri']},
#  {'topics': ['crude'],
#   'places': ['ecuador', 'colombia'],
#   'title': ['ecuador', 'begin', 'work', 'pipelin', 'colombia'],
#   'body': ['construct',
#    'worker',
#    'today',
#    'began',
#    'build',
#    'mile',
#    'pipelin',
#    'link',
#    'ecuador',
#    'jungl',
#    'oilfield',
#    'pipelin',
#    'colombia',
#    'crude',
#    'pump',
#    'pacif',
#    'coast',
#    'energi',
#    'offici',
#    'said',
#    'said',
#    'take',
#    'month',
#    'least',
#    'build',
#    'pipelin',
#    'ecuador',
#    'colon',
#    'colombia',
#    'connect',
#    'colombian',
#    'pipelin',
#    'port',
#    'colombia',
#    'pacif',
#    'ocean',
#    'coast',
#    'colon',
#    'pipelin',
#    'design',
#    'transport',
#    'barrel',
#    'crude',
#    'colombian',
#    'pipelin',
#    'said',
#    'colombian',
#    'pipelin',
#    'ampl',
#    'room',
#    'crude',
#    'said',
#    'current',
#    'transport',
#    'capac',
#    'energi',
#    'ministri',
#    'offici',
#    'said',
#    'crude',
#    'reach',
#    'ship',
#    'boat',
#    'ecuador',
#    'refin',
#    'product',
#    'meet',
#    'domest',
#    'demand',
#    'complet',
#    'pipelin',
#    'allow',
#    'ecuador',
#    'resum',
#    'product',
#    'paralys',
#    'march',
#    'earthquak',
#    'night',
#    'tremor',
#    'ruptur',
#    'countri',
#    'main',
#    'pipelin',
#    'jungl',
#    'oilfield',
#    'port',
#    'pacif',
#    'ocean',
#    'ecuador',
#    'pump',
#    'earthquak',
#    'take',
#    'five',
#    'month',
#    'repair',
#    'pipelin',
#    'govern',
#    'offici',
#    'said',
#    'ecuador',
#    'estim',
#    'cost',
#    'repair',
#    'instal',
#    'damag',
#    'earthquak',
#    'energi',
#    'ministri',
#    'said']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['usda', 'export', 'bonu', 'said', 'affect', 'trade', 'talk'],
#   'body': ['agricultur',
#    'depart',
#    'export',
#    'enhanc',
#    'program',
#    'contribut',
#    'recent',
#    'agreement',
#    'includ',
#    'farm',
#    'subsidi',
#    'round',
#    'global',
#    'trade',
#    'talk',
#    'accord',
#    'gener',
#    'account',
#    'offic',
#    'senior',
#    'associ',
#    'director',
#    'told',
#    'senat',
#    'agricultur',
#    'subcommitte',
#    'increas',
#    'cost',
#    'european',
#    'commun',
#    'common',
#    'agricultur',
#    'polici',
#    'howev',
#    'littl',
#    'reason',
#    'believ',
#    'expir',
#    'gain',
#    'farm',
#    'export',
#    'attribut',
#    'program',
#    'sustain',
#    'target',
#    'market',
#    'said',
#    'said',
#    'broaden',
#    'make',
#    'elimin',
#    'charg',
#    'discrimin',
#    'tradit',
#    'buyer',
#    'increas',
#    'pressur',
#    'antagon',
#    'export']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['burnham', 'report', 'underwrit', 'result'],
#   'body': ['burnham',
#    'lambert',
#    'said',
#    'first',
#    'nine',
#    'week',
#    'march',
#    'manag',
#    'transact',
#    'repres',
#    'billion',
#    'public',
#    'privat',
#    'corpor',
#    'market',
#    'overal',
#    'said',
#    'rank',
#    'fifth',
#    'categori',
#    'period',
#    'market',
#    'share',
#    'eight',
#    'period',
#    'last',
#    'year',
#    'said',
#    'market',
#    'share',
#    'lead',
#    'manag',
#    'industri',
#    'financ',
#    'also',
#    'increas',
#    'nine',
#    'week',
#    'period']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['boost', 'price', 'fifth', 'avenu'],
#   'body': ['corp',
#    'motor',
#    'unit',
#    'said',
#    'increas',
#    'price',
#    'fifth',
#    'avenu',
#    'luxuri',
#    'sedan',
#    'higher',
#    'price',
#    'appli',
#    'produc',
#    'american',
#    'motor',
#    'corp',
#    'assembl',
#    'plant',
#    'share',
#    'product',
#    'american',
#    'motor',
#    'shipment',
#    'began',
#    'march',
#    'nine',
#    'past',
#    'year',
#    'transfer',
#    'product',
#    'fifth',
#    'avenu',
#    'model',
#    'loui',
#    'number',
#    'facil',
#    'spokesman',
#    'said',
#    'price',
#    'increas',
#    'cover',
#    'cost',
#    'move',
#    'product',
#    'line',
#    'spokesman',
#    'said',
#    'higher',
#    'price',
#    'appli',
#    'fifth',
#    'avenu',
#    'price',
#    'plymouth',
#    'gran',
#    'furi',
#    'dodg',
#    'remain',
#    'unchang',
#    'move',
#    'product',
#    'three',
#    'larg',
#    'order',
#    'build',
#    'stretch',
#    'minivan',
#    'loui',
#    'facil',
#    'spokesman',
#    'said',
#    'first',
#    'stretch',
#    'minivan',
#    'roll',
#    'line',
#    'later',
#    'month']},
#  {'topics': ['trade'],
#   'places': ['netherlands'],
#   'title': ['dutch', 'trade', 'fulli', 'balanc', 'januari'],
#   'body': ['netherland',
#    'record',
#    'flat',
#    'trade',
#    'balanc',
#    'januari',
#    'export',
#    'import',
#    'total',
#    'billion',
#    'guilder',
#    'modestli',
#    'lower',
#    'compar',
#    'decemb',
#    'sharpli',
#    'januari',
#    'last',
#    'year',
#    'econom',
#    'ministri',
#    'spokesman',
#    'said',
#    'quot',
#    'offici',
#    'statist',
#    'januari',
#    'export',
#    'compar',
#    'decemb',
#    'figur',
#    'billion',
#    'guilder',
#    'last',
#    'year',
#    'level',
#    'billion',
#    'januari',
#    'import',
#    'compar',
#    'billion',
#    'guilder',
#    'decemb',
#    'fell',
#    'billion',
#    'januari',
#    'last',
#    'year']},
#  {'topics': ['grain', 'corn'],
#   'places': ['ussr', 'usa', 'argentina'],
#   'title': ['numer', 'factor', 'said', 'point', 'ussr', 'corn'],
#   'body': ['greater',
#    'anticip',
#    'need',
#    'competit',
#    'price',
#    'polit',
#    'motiv',
#    'spark',
#    'soviet',
#    'interest',
#    'corn',
#    'industri',
#    'govern',
#    'offici',
#    'said',
#    'rumor',
#    'circul',
#    'grain',
#    'market',
#    'today',
#    'soviet',
#    'union',
#    'purchas',
#    'addit',
#    'tonn',
#    'corn',
#    'industri',
#    'govern',
#    'sourc',
#    'note',
#    'number',
#    'factor',
#    'make',
#    'soviet',
#    'corn',
#    'like',
#    'first',
#    'suppli',
#    'concern',
#    'trade',
#    'sourc',
#    'said',
#    'recent',
#    'specul',
#    'last',
#    'year',
#    'soviet',
#    'grain',
#    'crop',
#    'revis',
#    'tonn',
#    'rather',
#    'announc',
#    'increas',
#    'soviet',
#    'need',
#    'grain',
#    'drop',
#    'argentin',
#    'corn',
#    'crop',
#    'prospect',
#    'also',
#    'affect',
#    'soviet',
#    'corn',
#    'agricultur',
#    'depart',
#    'sourc',
#    'said',
#    'weather',
#    'argentina',
#    'major',
#    'corn',
#    'supplier',
#    'ussr',
#    'report',
#    'crop',
#    'problem',
#    'prompt',
#    'usda',
#    'lower',
#    'argentin',
#    'corn',
#    'crop',
#    'estim',
#    'week',
#    'tonn',
#    'argentina',
#    'corn',
#    'export',
#    'also',
#    'tonn',
#    'tonn',
#    'argentina',
#    'alreadi',
#    'commit',
#    'four',
#    'tonn',
#    'year',
#    'corn',
#    'export',
#    'usda',
#    'offici',
#    'said',
#    'tonn',
#    'book',
#    'deliveri',
#    'ussr',
#    'signific',
#    'downsid',
#    'potenti',
#    'still',
#    'exist',
#    'argentin',
#    'crop',
#    'offici',
#    'said',
#    'decreas',
#    'amount',
#    'addit',
#    'corn',
#    'countri',
#    'sell',
#    'moscow',
#    'soviet',
#    'need',
#    'greater',
#    'think',
#    'might',
#    'need',
#    'argentina',
#    'provid',
#    'april',
#    'june',
#    'period',
#    'said',
#    'current',
#    'competit',
#    'price',
#    'corn',
#    'also',
#    'spark',
#    'soviet',
#    'corn',
#    'report',
#    'sell',
#    'world',
#    'market',
#    'earlier',
#    'week',
#    'around',
#    'tonn',
#    'argentin',
#    'corn',
#    'competit',
#    'price',
#    'spread',
#    'soviet',
#    'sourc',
#    'said',
#    'price',
#    'differ',
#    'make',
#    'american',
#    'corn',
#    'competit',
#    'albert',
#    'commerci',
#    'counselor',
#    'soviet',
#    'union',
#    'told',
#    'impend',
#    'crop',
#    'problem',
#    'argentina',
#    'like',
#    'caus',
#    'price',
#    'rise',
#    'recent',
#    'strong',
#    'corn',
#    'futur',
#    'price',
#    'soviet',
#    'might',
#    'feel',
#    'corn',
#    'price',
#    'bottom',
#    'good',
#    'time',
#    'sourc',
#    'said',
#    'final',
#    'industri',
#    'sourc',
#    'said',
#    'minimum',
#    'amount',
#    'corn',
#    'guarante',
#    'grain',
#    'agreement',
#    'four',
#    'tonn',
#    'soviet',
#    'union',
#    'hope',
#    'convinc',
#    'usda',
#    'offer',
#    'moscow',
#    'subsidi',
#    'wheat',
#    'week',
#    'usda',
#    'secretari',
#    'said',
#    'decis',
#    'made',
#    'wheat',
#    'subsidi',
#    'offer',
#    'offer',
#    'rule']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['industri', 'close', 'plant'],
#   'body': ['industri',
#    'said',
#    'close',
#    'republ',
#    'plant',
#    'year',
#    'sell',
#    'next',
#    'year',
#    'agre',
#    'forc',
#    'termin',
#    'trainer',
#    'aircraft',
#    'program',
#    'john',
#    'republ',
#    'unit',
#    'presid',
#    'vice',
#    'presid',
#    'corpor',
#    'said',
#    'fulfil',
#    'remain',
#    'current',
#    'oblig',
#    'ceas',
#    'work',
#    'immedi',
#    'said',
#    'unit',
#    'alreadi',
#    'deliv',
#    'product',
#    'said',
#    'lack',
#    'addit',
#    'forc',
#    'fund',
#    'trainer',
#    'budget',
#    'constraint',
#    'prompt',
#    'termin',
#    'agreement',
#    'busi',
#    'replac',
#    'work',
#    'forc',
#    'close',
#    'plant',
#    'said',
#    'expect',
#    'retain',
#    'engin',
#    'technician',
#    'small',
#    'oper',
#    'long',
#    'island',
#    'continu',
#    'provid',
#    'technic',
#    'support',
#    'forc',
#    'aircraft',
#    'center',
#    'formerli',
#    'part',
#    'republ',
#    'oper',
#    'becom',
#    'independ',
#    'oper',
#    'paul',
#    'wright',
#    'presid',
#    'chief',
#    'oper',
#    'offic',
#    'said',
#    'settlement',
#    'issu',
#    'behind',
#    'last',
#    'problem',
#    'aircraft',
#    'program',
#    'caus',
#    'compani',
#    'heavi',
#    'loss',
#    'past',
#    'year',
#    'wright',
#    'compani',
#    'move',
#    'forward',
#    'restructur',
#    'emphas',
#    'growth',
#    'area',
#    'aerospac',
#    'commun',
#    'electron',
#    'commerci',
#    'industri',
#    'busi',
#    'earlier',
#    'report',
#    'loss',
#    'continu',
#    'oper',
#    'share',
#    'compar',
#    'oper',
#    'profit',
#    'loss',
#    'eight',
#    'share',
#    'subtract',
#    'provis',
#    'prefer',
#    'share',
#    'fourth',
#    'quarter',
#    'report',
#    'oper',
#    'loss',
#    'share',
#    'provis',
#    'prefer',
#    'share',
#    'loss',
#    'share']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['regular', 'dividend'],
#   'body': ['previous', 'april', 'record', 'march']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['electron', 'regular'],
#   'body': ['class', 'prior', 'class', 'prior', 'april', 'record', 'april']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['texa', 'unit', 'seek', 'rate', 'refund'],
#   'body': ['texa',
#    'util',
#    'electr',
#    'unit',
#    'said',
#    'file',
#    'applic',
#    'texa',
#    'public',
#    'util',
#    'commiss',
#    'author',
#    'refund',
#    'custom',
#    'refund',
#    'fifth',
#    'made',
#    'possibl',
#    'lower',
#    'cost',
#    'fuel',
#    'make',
#    'electr',
#    'compani',
#    'said']},
#  {'topics': ['ipi'],
#   'places': ['brazil'],
#   'title': ['brazil', 'industri', 'growth', 'rate', 'slow', 'januari'],
#   'body': ['growth',
#    'rate',
#    'brazilian',
#    'industri',
#    'output',
#    'slow',
#    'januari',
#    'month',
#    'rise',
#    'decemb',
#    'brazilian',
#    'geographi',
#    'statist',
#    'institut',
#    'figur',
#    'show',
#    'result',
#    'line',
#    'declin',
#    'trend',
#    'growth',
#    'rate',
#    'octob',
#    'institut',
#    'said',
#    'month',
#    'industri',
#    'product',
#    'month',
#    'last',
#    'year',
#    'calendar',
#    'output',
#    'biggest',
#    'output',
#    'rise',
#    'month',
#    'pharmaceut',
#    'machineri']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['sell', 'sink', 'fund', 'debentur'],
#   'body': ['rais',
#    'issu',
#    'sink',
#    'fund',
#    'debentur',
#    'yield',
#    'said',
#    'lead',
#    'manag',
#    'brother',
#    'debentur',
#    'coupon',
#    'price',
#    'yield',
#    'basi',
#    'point',
#    'treasuri',
#    'bond',
#    'year',
#    'issu',
#    'rate',
#    'moodi',
#    'standard',
#    'poor',
#    'sink',
#    'fund',
#    'begin',
#    'retir',
#    'annual',
#    'five',
#    'debentur',
#    'increas',
#    'compani',
#    'option',
#    'read',
#    'deal']},
#  {'topics': [],
#   'places': ['uk', 'japan'],
#   'title': ['britain', 'want', 'bank', 'regul', 'deal', 'japan'],
#   'body': ['britain',
#    'want',
#    'japan',
#    'agre',
#    'timet',
#    'work',
#    'joint',
#    'rule',
#    'capit',
#    'adequaci',
#    'bank',
#    'along',
#    'line',
#    'januari',
#    'outlin',
#    'agreement',
#    'corpor',
#    'affair',
#    'minist',
#    'michael',
#    'howard',
#    'said',
#    'howard',
#    'told',
#    'confer',
#    'tokyo',
#    'financi',
#    'market',
#    'want',
#    'agreement',
#    'progress',
#    'made',
#    'rate',
#    'happen',
#    'japanes',
#    'financ',
#    'intern',
#    'affair',
#    'told',
#    'confer',
#    'yesterday',
#    'readi',
#    'discu',
#    'capit',
#    'adequaci',
#    'negoti',
#    'plan',
#    'agreement',
#    'reach',
#    'howard',
#    'said',
#    'anoth',
#    'issu',
#    'rais',
#    'visit',
#    'japan',
#    'start',
#    'april',
#    'equal',
#    'access',
#    'financi',
#    'firm',
#    'japanes',
#    'market',
#    'said',
#    'financi',
#    'firm',
#    'base',
#    'tokyo',
#    'nine',
#    'wholli',
#    'british',
#    'licenc',
#    'deal',
#    'secur',
#    'compar',
#    'japanes',
#    'firm',
#    'london',
#    'protectionist',
#    'welcom',
#    'firm',
#    'want',
#    'firm',
#    'compet',
#    'freeli',
#    'japan',
#    'moment',
#    'allow',
#    'said']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['system', 'name', 'presid'],
#   'body': ['system',
#    'said',
#    'mark',
#    'cote',
#    'appoint',
#    'presid',
#    'compani',
#    'system',
#    'subsidiari',
#    'compani',
#    'said',
#    'succe',
#    'david',
#    'accept',
#    'presid',
#    'shelf',
#    'storag',
#    'system',
#    'intern']},
#  {'topics': [],
#   'places': ['usa'],
#   'title': ['moodi', 'downgrad', 'home', 'shop', 'debt'],
#   'body': ['moodi',
#    'investor',
#    'servic',
#    'said',
#    'downgrad',
#    'home',
#    'shop',
#    'network',
#    'senior',
#    'note',
#    'rate',
#    'agenc',
#    'cite',
#    'home',
#    'shop',
#    'plan',
#    'issu',
#    'addit',
#    'debt',
#    'therebi',
#    'increas',
#    'leverag',
#    'moodi',
#    'note',
#    'compani',
#    'intend',
#    'portion',
#    'proce',
#    'repurchas',
#    'exist',
#    'debt',
#    'moodi',
#    'said',
#    'review',
#    'focu',
#    'home',
#    'shop',
#    'futur',
#    'capit',
#    'structur',
#    'examin',
#    'risk',
#    'associ',
#    'compani',
#    'commit',
#    'diversifi',
#    'product',
#    'line',
#    'includ',
#    'financi',
#    'servic']},
#  {'topics': ['earn'],
#   'places': ['usa'],
#   'title': ['gener', 'cinema', 'corp', 'common', 'stock', 'dividend'],
#   'body': ['prior', 'april', 'april', 'nine']},
#  {'topics': ['earn'], 'places': ['usa'], 'title': ['year'], 'body': []},
#  {'topics': [],
#   'places': [],
#   'title': ['usda',
#    'report',
#    'enrol',
#    'fourth',
#    'conserv',
#    'reserv',
#    'program'],
#   'body': []},
#  ...]

# %%
df_docs = pd.DataFrame.from_dict(documents)

# %%
import re
def split_it(df_docs):
    for col in df_docs.columns:
        df_docs[col] = df_docs[col].apply(str)
        df_docs[col] =  df_docs[col].apply(lambda x: x.replace('[','').replace(']','').replace('\'','')) 
    return df_docs

df_filter = split_it(df_docs)
df_filter
# Out:
#                                                     body  \
# 0      said, expect, earlier, report, remov, jone, in...
# 1      mason, former, presid, chief, oper, offic, emp...
# 2      discoveri, complic, search, vaccin, team, armi...
# 3      doctor, center, diseas, control, atlanta, said...
# 4      econom, data, week, determin, interest, rate, ...
# 5      reagan, administr, respond, last, year, unit, ...
# 6      novel, type, financ, texa, instrument, market,...
# 7      canadian, foreign, secretari, clark, wind, vis...
# 8      ford, motor, said, check, distribut, employe, ...
# 9      jamaica, billion, foreign, debt, reduc, oblig,...
# 10     team, california, research, said, develop, bet...
# 11     loss, profit, three, profit, profit, year, per...
# 12     albert, hakim, merchant, first, player, iran, ...
# 13     year, note, includ, loss, share, restat, give,...
# 14     loss, loss, year, loss, loss, loss, note, year...
# 15     corp, said, prove, reserv, natur, liquid, fell...
# 16     petroleum, chairman, said, compani, stock, ran...
# 17     michigan, gener, corp, said, began, exchang, o...
# 18     bank, british, columbia, said, revis, estim, s...
# 19     hous, vote, block, militari, nicaraguan, rebel...
# 20                                                  year
# 21     argentin, meat, export, total, tonn, tonn, shi...
# 22     gold, mine, said, plan, common, stock, split, ...
# 23     vanzetti, system, said, sharehold, approv, inc...
# 24               four, four, prior, april, record, march
# 25     hous, trade, lawmak, took, first, vote, measur...
# 26     soviet, first, deputi, prime, minist, said, br...
# 27     venezuela, suppli, ecuador, undetermin, amount...
# 28     profit, profit, profit, profit, month, profit,...
# 29     iraq, said, repel, iranian, attack, posit, hel...
# ...                                                  ...
# 20548  corp, said, sale, rose, three, month, august, ...
# 20549  cabl, wireless, said, merg, telephon, cabl, wi...
# 20550  nine, month, august, group, group, billion, bi...
# 20551
# 20552  third, quarter, august, group, group, billion,...
# 20553
# 20554
# 20555  french, financ, minist, issu, firm, call, cont...
# 20556  intern, rubber, organis, buffer, stock, manag,...
# 20557  continent, airlin, said, frontier, airlin, bou...
# 20558
# 20559  nippon, agre, intern, issu, credit, card, call...
# 20560  incom, surcharg, capit, gain, bring, urgent, n...
# 20561  philippin, trade, deficit, widen, eight, month...
# 20562  iranian, presid, said, doubt, posit, take, vio...
# 20563
# 20564  zealand, impos, sanction, fiji, respons, count...
# 20565  ministri, financ, start, consid, coupon, rate,...
# 20566  uganda, plan, export, roast, coffe, europ, pro...
# 20567  soviet, union, agre, suppli, iran, refin, prod...
# 20568  order, import, place, august, rose, season, ad...
# 20569  thai, rice, export, rose, tonn, week, octob, p...
# 20570  chase, corp, said, make, offer, share, option,...
# 20571  announc, comput, system, system, unveil, machi...
# 20572  tokyo, foreign, exchang, market, watch, nervou...
# 20573  ship, confer, said, extra, risk, insur, surcha...
# 20574  soviet, union, industri, output, grow, slower,...
# 20575  black, miner, kill, injur, rock, fall, three, ...
# 20576  prospect, domin, allianc, socialist, environme...
# 20577  american, stock, exchang, said, introduc, opti...
#
#                                               places  \
# 0                                             canada
# 1                                                usa
# 2                                                usa
# 3                                                usa
# 4                                                usa
# 5                                                usa
# 6                                                usa
# 7                                        usa, canada
# 8                                                usa
# 9                                            jamaica
# 10                                               usa
# 11                                            canada
# 12                                         usa, iran
# 13                                               usa
# 14                                               usa
# 15                                        usa, libya
# 16                                               usa
# 17                                               usa
# 18                                            canada
# 19                                               usa
# 20                                            canada
# 21                                         argentina
# 22                                            canada
# 23                                               usa
# 24                                               usa
# 25                                               usa
# 26                                      france, ussr
# 27                                ecuador, venezuela
# 28                                               usa
# 29                                        iran, iraq
# ...                                              ...
# 20548                                          japan
# 20549                                      hong-kong
# 20550                                          japan
# 20551
# 20552                                          japan
# 20553
# 20554
# 20555                                         france
# 20556                                       malaysia
# 20557                                            usa
# 20558
# 20559                                          japan
# 20560                                    new-zealand
# 20561                                    philippines
# 20562                                      usa, iran
# 20563
# 20564                              new-zealand, fiji
# 20565                                     japan, usa
# 20566                                         uganda
# 20567                             iran, ussr, cyprus
# 20568                                    new-zealand
# 20569                                       thailand
# 20570                                    new-zealand
# 20571                                            usa
# 20572                       japan, west-germany, usa
# 20573  hong-kong, japan, india, pakistan, iran, iraq
# 20574                                           ussr
# 20575                                   south-africa
# 20576                                    switzerland
# 20577                                            usa
#
#                                                    title  \
# 0                                   major, impact, remov
# 1                 former, empir, carolina, exec, sentenc
# 2                     doctor, find, link, smallpox, viru
# 3      birth, control, pill, help, prevent, cancer, s...
# 4                     econom, data, debt, futur, outlook
# 5                                action, program, africa
# 6                 unusu, texa, instrument, prefer, price
# 7                      clark, expect, action, acid, rain
# 8                  ford, motor, distribut, profit, share
# 9                                        jamaica, borrow
# 10            faster, test, sickl, cell, anemia, develop
# 11                               bank, british, columbia
# 12                       scandal, particip, immun, offer
# 13                                       restaur, associ
# 14                                 michigan, gener, corp
# 15                                   prove, reserv, fall
# 16                               stock, step, pare, debt
# 17                michigan, gener, begin, exchang, offer
# 18                             bank, revis, share, estim
# 19                      hous, vote, block, contra, month
# 20                                            gold, mine
# 21                        argentin, meat, export, higher
# 22                                    plan, stock, split
# 23                      vanzetti, increas, share, approv
# 24                              furnitur, corp, dividend
# 25           hous, panel, take, first, trade, bill, vote
# 26                  soviet, minist, trade, boost, french
# 27                      venezuela, lend, ecuador, export
# 28                                           eagl, cloth
# 29           iraq, iran, attack, repuls, southern, front
# ...                                                  ...
# 20548                   sale, rise, electron, part, sale
# 20549               cabl, wireless, detail, merger, unit
# 20550                                 group, nine, month
# 20551  share, index, open, point, london, stock, exchang
# 20552                        group, three, month, august
# 20553  share, index, open, point, london, stock, exchang
# 20554       cabl, wireless, merg, unit, telecommun, oper
# 20555                     insist, mainten, louvr, accord
# 20556              rubber, stock, manag, qualiti, accept
# 20557  frontier, airlin, seek, faster, claim, settlement
# 20558   hang, stock, index, lose, point, late, afternoon
# 20559                         nippon, issu, credit, card
# 20560                           economist, lower, dollar
# 20561                            philippin, trade, widen
# 20562                  iran, presid, doubt, action, iran
# 20563           tokyo, stock, index, close, point, lower
# 20564                     zealand, impos, sanction, fiji
# 20565         japan, start, consid, novemb, bond, coupon
# 20566          uganda, plan, export, roast, coffe, europ
# 20567   iran, soviet, union, swap, crude, refin, product
# 20568               zealand, import, order, rise, august
# 20569              thai, rice, export, rise, week, octob
# 20570                           chase, corp, make, offer
# 20571                                  competit, toughen
# 20572                tokyo, dealer, dollar, pois, breach
# 20573                          confer, gulf, risk, charg
# 20574                           soviet, industri, slower
# 20575            kill, south, african, gold, mine, accid
# 20576           project, show, swiss, voter, want, parti
# 20577       american, exchang, introduc, institut, index
#
#                            topics
# 0
# 1
# 2
# 3
# 4           interest, retail, ipi
# 5
# 6
# 7
# 8
# 9
# 10
# 11                           earn
# 12
# 13                           earn
# 14                           earn
# 15     crude, nat-gas, iron-steel
# 16
# 17
# 18                           earn
# 19
# 20                           earn
# 21             carcass, livestock
# 22                           earn
# 23
# 24                           earn
# 25                          trade
# 26                          trade
# 27                          crude
# 28                           earn
# 29
# ...                           ...
# 20548
# 20549                         acq
# 20550                        earn
# 20551
# 20552                        earn
# 20553
# 20554                         acq
# 20555                    money-fx
# 20556                      rubber
# 20557
# 20558
# 20559
# 20560             money-fx, nzdlr
# 20561                       trade
# 20562
# 20563
# 20564                       sugar
# 20565
# 20566                      coffee
# 20567                       crude
# 20568
# 20569                 grain, rice
# 20570                         acq
# 20571
# 20572          money-fx, dlr, yen
# 20573                        ship
# 20574                         ipi
# 20575                        gold
# 20576
# 20577
#
# [20578 rows x 4 columns]

# %% [markdown]
# **Storing the dataframe in CSV**

# %%
df_docs.to_csv('Documents_Complete.csv', index = False)
